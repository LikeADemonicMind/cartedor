# %% [markdown]
# # Projet : réaliser une étude sur les produits alimentaires

# %% [markdown]
# ## 1 - Contexte

# %% [markdown]
# Vous réalisez une mission "UFC-Que Choisir". Cette association vous demande de réaliser une étude
# sur la qualité des produits alimentaires mis à disposition des consommateurs par les marques. Cette étude a vocation à aider les consommateurs dans leurs choix.

# %% [markdown]
# L'objectif est d'analyser les marques sur au moins les critères suivants : la qualité nutritionnelle, l'impact environnemental, la part des produits biologiques.

# %% [markdown]
# Pour cela, vous proposer d'utiliser les données de l'application Yuka

# %% [markdown]
# Voici une liste des questions que se pose l'association :
#
# - Quelles sont les marques qui jouent le jeu et affichent le nutriscore ? Lesquelles ne le font pas?
#
# - Quelles sont les marques qui ont le plus recours aux additifs nocifs
#
# - Quelles sont les marques qui présentent des produits avec la meilleure qualité nutritionnelle ? Les pires ?
#
# - Quelles sont les marques qui jouent le jeu et affichent l'ecosore ? Lesquelles ne le font pas?
#
# - Quelles sont les marques qui semblent le plus respectueuses de l'environnement ? le moins?
#
# - Quelles sont les marques qui proposent essentiellement des produits biologiques ?
#
# - Observe-t-on une corrélation entre le caratère bio des produits et la qualité nutritionnelle ?
#
# - Observe-t-on une corrélation entre le caratère bio des produits et l'aspect envionnemental ?
#
# - Observe-t-on une corrélation entre la la qualité nutritionnelle et l'aspec envionnemental ?
#
# - Quelles marques faut-il recommander ?
#
# - Quelles marques ne faut-il surtout pas recommander ?

# %% [markdown]
# ## 2 - Données

# %% [markdown]
# 3 fichiers issues de l'application Yuka sont à exploiter pour réaliser l'analyse.

# %% [markdown]
# Agriculture_biologique_final.csv
#
# Qualite nutritionnelle_final.csv
#
# Impact environnemental_final.csv

# %% [markdown]
# Voici le lien pour récupérer les fichiers

# %% [markdown]
# # https://www.dropbox.com/sh/pwsv4coi2sbbhyo/AABJ81-xWu3K2Cl0DOCmwbGsa?dl=0

# %% [markdown]
# ## 3 - Consignes

# %% [markdown]
# Travail de groupe de 3 personnes.
#
# Pour l'évaluation CC, chaque groupe doit livrer à la fin des sessions :
#
#     - un rapport synthétisant l'analyse faite et les conculusions obtenues
#
#     - un notebook nettoyé et commenté

# %% [markdown]
# ## 4 - Contraintes !!!
#
# Votre analyse doit inclure des analyses univariées et multivariées

# %% [markdown]
# ## 5 - Préparation de l'environnement

# %%
# Import de la librairie Pandas
import pandas as pd

# Import de la librairie matplotlib
import matplotlib.pyplot as plt

#Import de numpy
import numpy as np

from scipy import stats

# %% [markdown]
# ## 6 - A vous de jouer¶

# %% [markdown]
# Inspirez-vous du TP vu en cours

# %%
bio = pd.read_csv("Agriculture_biologique_final.csv", sep ="\t", low_memory = False)
qnutri = pd.read_csv("Qualite nutritionnelle_final.csv", sep ="\t", low_memory = False)
ienvi = pd.read_csv("Impact environnemental_final.csv", sep ="\t", low_memory = False)

# %%
qnutri
# Out:
#                         code                  product_name quantity  \
# 0       00000000000026772226                          Skyr    480 g
# 1              0000000000017              Vitória crackers      NaN
# 2              0000000000031                         Cacao    130 g
# 3              0000000000100   moutarde au moût de raisin      100g
# 4              0000000000123         Sauce Sweety chili 0%      NaN
# ...                      ...                           ...      ...
# 932861         9999991953895              Crème de Marrons      NaN
# 932862         9999992756068                   Steak haché    500 g
# 932863         9999992756112                   Steak haché     1 kg
# 932864             999999999       Thé noir BIO Darjeeling      NaN
# 932865         9999999999994     Light & Free SKYR A BOIRE      NaN
#
#           brands_tags countries_tags serving_size  \
# 0              danone      en:france          NaN
# 1                 NaN      en:france          NaN
# 2                 NaN      en:france          NaN
# 3       courte-paille      en:france          NaN
# 4                 NaN      en:france          NaN
# ...               ...            ...          ...
# 932861            NaN      en:france          NaN
# 932862            NaN      en:france          NaN
# 932863            NaN      en:france          NaN
# 932864          pages      en:france          NaN
# 932865            NaN      en:france          NaN
#
#                                                 image_url  \
# 0       https://images.openfoodfacts.org/images/produc...
# 1       https://images.openfoodfacts.org/images/produc...
# 2       https://images.openfoodfacts.org/images/produc...
# 3       https://images.openfoodfacts.org/images/produc...
# 4       https://images.openfoodfacts.org/images/produc...
# ...                                                   ...
# 932861  https://images.openfoodfacts.org/images/produc...
# 932862  https://images.openfoodfacts.org/images/produc...
# 932863  https://images.openfoodfacts.org/images/produc...
# 932864                                                NaN
# 932865  https://images.openfoodfacts.org/images/produc...
#
#                                          ingredients_tags nutriscore_grade  \
# 0                                                     NaN                a
# 1                                                     NaN              NaN
# 2                                                     NaN              NaN
# 3       fr:eau-graines-de-teguments-de-moutarde-vinaig...                d
# 4                                                     NaN              NaN
# ...                                                   ...              ...
# 932861                                                NaN              NaN
# 932862                                                NaN              NaN
# 932863                                                NaN              NaN
# 932864                                                NaN              NaN
# 932865                                                NaN                e
#
#         energy-kcal_100g  fat_100g  saturated-fat_100g  sugars_100g  \
# 0                   57.0       0.2                0.10          3.9
# 1                  375.0       7.0                3.08         15.0
# 2                    NaN       NaN                 NaN          NaN
# 3                    NaN       8.2                2.20         22.0
# 4                   21.0       0.0                0.00          0.4
# ...                  ...       ...                 ...          ...
# 932861               NaN       NaN                 NaN          NaN
# 932862               NaN       NaN                 NaN          NaN
# 932863             196.0      14.0                6.20          0.0
# 932864               NaN       NaN                 NaN          NaN
# 932865              24.0      28.0               13.00         49.0
#
#         proteins_100g  salt_100g  nb_nocif
# 0                10.0       0.09       0.0
# 1                 7.8       1.40       0.0
# 2                 NaN        NaN       0.0
# 3                 5.1       4.60       0.0
# 4                 0.2       2.04       0.0
# ...               ...        ...       ...
# 932861            NaN        NaN       0.0
# 932862            NaN        NaN       0.0
# 932863           19.0       0.19       0.0
# 932864            NaN        NaN       0.0
# 932865            2.0       3.00       0.0
#
# [932866 rows x 16 columns]

# %%
qnutri_sansna = qnutri[qnutri['brands_tags'].notna()]
qnutri_sansna = qnutri_sansna[qnutri_sansna['product_name'].notna()]
qnutri_sansna_duplicate = qnutri_sansna.drop_duplicates()

# %%
qnutri_sansna.isna().sum()
# Out:
# code                       0
# product_name               0
# quantity              218560
# brands_tags                0
# countries_tags             0
# serving_size          371014
# image_url              44793
# ingredients_tags      211980
# nutriscore_grade      215168
# energy-kcal_100g      101616
# fat_100g               81497
# saturated-fat_100g     81139
# sugars_100g            80248
# proteins_100g          79666
# salt_100g              87962
# nb_nocif                   0
# dtype: int64

# %%
qnutri_sansna.duplicated().sum()
# Out:
# 31967

# %%
qnutri_sansna_duplicate
# Out:
#                         code                         product_name quantity  \
# 0       00000000000026772226                                 Skyr    480 g
# 3              0000000000100          moutarde au moût de raisin      100g
# 15             0000000001199               Solène céréales poulet      NaN
# 16             0000000001281                   Tarte noix de coco      NaN
# 20             0000000001663               Crème dessert chocolat      NaN
# ...                      ...                                  ...      ...
# 932782              99665555               La parisienne à poêler      NaN
# 932784                997046              Chocolat noir patissier      NaN
# 932792                998042                       Saveur ABRICIT      NaN
# 932803               9990000                Lindt pâte à tartiner      NaN
# 932820            9995545314  Biodrink antioxydant pendant effort      NaN
#
#                     brands_tags countries_tags serving_size  \
# 0                        danone      en:france          NaN
# 3                 courte-paille      en:france          NaN
# 15                        crous      en:france          NaN
# 16            crous-resto,crous      en:france          NaN
# 20      ferme-de-la-fremondiere      en:france          NaN
# ...                         ...            ...          ...
# 932782                bonduelle      en:france          NaN
# 932784             monoprix-bio      en:france          NaN
# 932792                   gerble      en:france          NaN
# 932803                    lindt      en:france          NaN
# 932820              punch-power      en:france          NaN
#
#                                                 image_url  \
# 0       https://images.openfoodfacts.org/images/produc...
# 3       https://images.openfoodfacts.org/images/produc...
# 15      https://images.openfoodfacts.org/images/produc...
# 16      https://images.openfoodfacts.org/images/produc...
# 20      https://images.openfoodfacts.org/images/produc...
# ...                                                   ...
# 932782  https://images.openfoodfacts.org/images/produc...
# 932784  https://images.openfoodfacts.org/images/produc...
# 932792  https://images.openfoodfacts.org/images/produc...
# 932803  https://images.openfoodfacts.org/images/produc...
# 932820  https://images.openfoodfacts.org/images/produc...
#
#                                          ingredients_tags nutriscore_grade  \
# 0                                                     NaN                a
# 3       fr:eau-graines-de-teguments-de-moutarde-vinaig...                d
# 15      en:antioxidant,en:colour,en:tomato,en:vegetabl...              NaN
# 16                                                    NaN                d
# 20      en:whole-milk,en:dairy,en:milk,en:sugar,en:add...              NaN
# ...                                                   ...              ...
# 932782                                                NaN              NaN
# 932784                                                NaN              NaN
# 932792                                                NaN              NaN
# 932803                                                NaN              NaN
# 932820                                                NaN              NaN
#
#         energy-kcal_100g  fat_100g  saturated-fat_100g  sugars_100g  \
# 0                   57.0       0.2                0.10          3.9
# 3                    NaN       8.2                2.20         22.0
# 15                 219.0       5.9                0.50          1.7
# 16                 381.0      22.0               15.50         21.9
# 20                   0.0       0.0                0.00          0.0
# ...                  ...       ...                 ...          ...
# 932782              52.0       0.6                0.10          2.1
# 932784             578.0      39.0               24.00         46.0
# 932792              45.0       1.8                0.01          1.5
# 932803               NaN       NaN                 NaN          NaN
# 932820             384.0       0.1                0.10         59.0
#
#         proteins_100g  salt_100g  nb_nocif
# 0                10.0      0.090       0.0
# 3                 5.1      4.600       0.0
# 15                9.7      0.464       0.0
# 16                4.6      0.100       0.0
# 20                0.0      0.000       0.0
# ...               ...        ...       ...
# 932782            1.7      0.470       0.0
# 932784            5.1      0.000       0.0
# 932792            9.7      0.130       0.0
# 932803            NaN        NaN       0.0
# 932820            0.1      1.500       0.0
#
# [424596 rows x 16 columns]

# %%
bio.isna().sum()
# Out:
# product_name      7359
# brands_tags          0
# serving_size    377744
# est_bio              0
# dtype: int64

# %%
bio_sansna = bio[bio['product_name'].notna()]

# %%
bio_sansna.isna().sum()
# Out:
# product_name         0
# brands_tags          0
# serving_size    371014
# est_bio              0
# dtype: int64

# %%
bio_sansna.duplicated().sum()
# Out:
# 59913

# %%
bio_sansna_duplicate = bio_sansna.drop_duplicates()

# %%
bio_sansna_duplicate
# Out:
#                                product_name              brands_tags  \
# 0                                      Skyr                   danone
# 1               moutarde au moût de raisin             courte-paille
# 2                    Solène céréales poulet                    crous
# 3                        Tarte noix de coco        crous-resto,crous
# 4                    Crème dessert chocolat  ferme-de-la-fremondiere
# ...                                     ...                      ...
# 463912                 Nutra'cake framboise                  delical
# 463915              Chocolat noir patissier             monoprix-bio
# 463917                       Saveur ABRICIT                   gerble
# 463918                Lindt pâte à tartiner                    lindt
# 463919  Biodrink antioxydant pendant effort              punch-power
#
#        serving_size  est_bio
# 0               NaN    False
# 1               NaN    False
# 2               NaN    False
# 3               NaN    False
# 4               NaN    False
# ...             ...      ...
# 463912          NaN    False
# 463915          NaN     True
# 463917          NaN    False
# 463918          NaN    False
# 463919          NaN     True
#
# [396650 rows x 4 columns]

# %%
bio_sansna_duplicate_gb = bio_sansna_duplicate.groupby(by=["product_name", "brands_tags"]).first().reset_index()
bio_sansna_duplicate_gb
# Out:
#                                   product_name               brands_tags  \
# 0                                                                    m-s
# 1                            18 marrons glacés                     motta
# 2                         6 Crêpes de sarrasin  les-delices-de-landeleau
# 3        Biscuit Tablette Chocolat au Lait bio                   u-bio,u
# 4                                      Boletus                      coop
# ...                                        ...                       ...
# 388821            자연은 튼튼 (Jayeon-eun Teunteun)            자연은,jayeon-eun
# 388822                    🍇 Raisins sultanines                  rapunzel
# 388823                           🍚Riz au lait🥛               la-fermiere
# 388824                    🐰 Lait du pays Alpin                     milka
# 388825                                       📖                  leclaire
#
#        serving_size  est_bio
# 0              None    False
# 1              None    False
# 2              None    False
# 3              25 g     True
# 4              10 g    False
# ...             ...      ...
# 388821      serving    False
# 388822         None     True
# 388823         160g    False
# 388824         100g    False
# 388825         None    False
#
# [388826 rows x 4 columns]

# %%
bio_sansna_duplicate_gb.duplicated().sum()
# Out:
# 0

# %%
bio_sansna_duplicate[bio_sansna_duplicate["product_name"]== "Skyr"]
# Out:
#        product_name          brands_tags        serving_size  est_bio
# 0              Skyr               danone                 NaN    False
# 5361           Skyr       liberte-canada             serving    False
# 15774          Skyr               danone                140g    False
# 22749          Skyr              siggi-s                140g    False
# 51822          Skyr               danone        1 pot (140g)    False
# 52248          Skyr               danone  5 cuill�res � caf�    False
# 151598         Skyr              yoplait                 NaN    False
# 185983         Skyr            logismose                 NaN    False
# 229277         Skyr  les-2-vaches,danone                120g     True
# 268429         Skyr              puffy-s                 NaN     True
# 276300         Skyr         milbona,lidl                 NaN    False
# 277519         Skyr              minus-l                 NaN    False
# 295074         Skyr            carrefour                 NaN    False
# 306009         Skyr           pingo-doce                 NaN    False
# 307519         Skyr                 isey                 NaN    False
# 307525         Skyr                 isey                150g    False
# 386706         Skyr           continente                 NaN    False
# 393922         Skyr              siggi-s                 NaN    False
# 442566         Skyr                 arla                 NaN    False
# 450812         Skyr            isey-skyr                100g    False

# %%
ienvi
# Out:
#                         code                  product_name quantity  \
# 0       00000000000026772226                          Skyr    480 g
# 1              0000000000017              Vitória crackers      NaN
# 2              0000000000031                         Cacao    130 g
# 3              0000000000100   moutarde au moût de raisin      100g
# 4              0000000000123         Sauce Sweety chili 0%      NaN
# ...                      ...                           ...      ...
# 932861         9999991953895              Crème de Marrons      NaN
# 932862         9999992756068                   Steak haché    500 g
# 932863         9999992756112                   Steak haché     1 kg
# 932864             999999999       Thé noir BIO Darjeeling      NaN
# 932865         9999999999994     Light & Free SKYR A BOIRE      NaN
#
#           brands_tags countries_tags serving_size  \
# 0              danone      en:france          NaN
# 1                 NaN      en:france          NaN
# 2                 NaN      en:france          NaN
# 3       courte-paille      en:france          NaN
# 4                 NaN      en:france          NaN
# ...               ...            ...          ...
# 932861            NaN      en:france          NaN
# 932862            NaN      en:france          NaN
# 932863            NaN      en:france          NaN
# 932864          pages      en:france          NaN
# 932865            NaN      en:france          NaN
#
#                                                 image_url ecoscore_grade  \
# 0       https://images.openfoodfacts.org/images/produc...              d
# 1       https://images.openfoodfacts.org/images/produc...        unknown
# 2       https://images.openfoodfacts.org/images/produc...        unknown
# 3       https://images.openfoodfacts.org/images/produc...              c
# 4       https://images.openfoodfacts.org/images/produc...        unknown
# ...                                                   ...            ...
# 932861  https://images.openfoodfacts.org/images/produc...        unknown
# 932862  https://images.openfoodfacts.org/images/produc...              e
# 932863  https://images.openfoodfacts.org/images/produc...        unknown
# 932864                                                NaN        unknown
# 932865  https://images.openfoodfacts.org/images/produc...        unknown
#
#         est_plastique  est_palm  est_cocoa
# 0               False     False      False
# 1               False     False      False
# 2               False     False      False
# 3               False     False      False
# 4               False     False      False
# ...               ...       ...        ...
# 932861          False     False      False
# 932862          False     False      False
# 932863          False     False      False
# 932864          False     False      False
# 932865          False     False      False
#
# [932866 rows x 11 columns]

# %%
ienvi_sansna = ienvi[ienvi['brands_tags'].notna()]
ienvi_sansna = ienvi_sansna[ienvi_sansna['product_name'].notna()]
ienvi_sansna_duplicate = ienvi_sansna.drop_duplicates()

# %%
# les colonnes en commun sont product_name et brands_tags
df_total = qnutri_sansna_duplicate.merge(ienvi_sansna_duplicate,on=['code'], how="inner", suffixes=('', '_DROP')).filter(regex='^(?!.*_DROP)')

# %%
df_total
# Out:
#                         code                         product_name quantity  \
# 0       00000000000026772226                                 Skyr    480 g
# 1              0000000000100          moutarde au moût de raisin      100g
# 2              0000000001199               Solène céréales poulet      NaN
# 3              0000000001281                   Tarte noix de coco      NaN
# 4              0000000001663               Crème dessert chocolat      NaN
# ...                      ...                                  ...      ...
# 424597              99665555               La parisienne à poêler      NaN
# 424598                997046              Chocolat noir patissier      NaN
# 424599                998042                       Saveur ABRICIT      NaN
# 424600               9990000                Lindt pâte à tartiner      NaN
# 424601            9995545314  Biodrink antioxydant pendant effort      NaN
#
#                     brands_tags countries_tags serving_size  \
# 0                        danone      en:france          NaN
# 1                 courte-paille      en:france          NaN
# 2                         crous      en:france          NaN
# 3             crous-resto,crous      en:france          NaN
# 4       ferme-de-la-fremondiere      en:france          NaN
# ...                         ...            ...          ...
# 424597                bonduelle      en:france          NaN
# 424598             monoprix-bio      en:france          NaN
# 424599                   gerble      en:france          NaN
# 424600                    lindt      en:france          NaN
# 424601              punch-power      en:france          NaN
#
#                                                 image_url  \
# 0       https://images.openfoodfacts.org/images/produc...
# 1       https://images.openfoodfacts.org/images/produc...
# 2       https://images.openfoodfacts.org/images/produc...
# 3       https://images.openfoodfacts.org/images/produc...
# 4       https://images.openfoodfacts.org/images/produc...
# ...                                                   ...
# 424597  https://images.openfoodfacts.org/images/produc...
# 424598  https://images.openfoodfacts.org/images/produc...
# 424599  https://images.openfoodfacts.org/images/produc...
# 424600  https://images.openfoodfacts.org/images/produc...
# 424601  https://images.openfoodfacts.org/images/produc...
#
#                                          ingredients_tags nutriscore_grade  \
# 0                                                     NaN                a
# 1       fr:eau-graines-de-teguments-de-moutarde-vinaig...                d
# 2       en:antioxidant,en:colour,en:tomato,en:vegetabl...              NaN
# 3                                                     NaN                d
# 4       en:whole-milk,en:dairy,en:milk,en:sugar,en:add...              NaN
# ...                                                   ...              ...
# 424597                                                NaN              NaN
# 424598                                                NaN              NaN
# 424599                                                NaN              NaN
# 424600                                                NaN              NaN
# 424601                                                NaN              NaN
#
#         energy-kcal_100g  fat_100g  saturated-fat_100g  sugars_100g  \
# 0                   57.0       0.2                0.10          3.9
# 1                    NaN       8.2                2.20         22.0
# 2                  219.0       5.9                0.50          1.7
# 3                  381.0      22.0               15.50         21.9
# 4                    0.0       0.0                0.00          0.0
# ...                  ...       ...                 ...          ...
# 424597              52.0       0.6                0.10          2.1
# 424598             578.0      39.0               24.00         46.0
# 424599              45.0       1.8                0.01          1.5
# 424600               NaN       NaN                 NaN          NaN
# 424601             384.0       0.1                0.10         59.0
#
#         proteins_100g  salt_100g  nb_nocif ecoscore_grade  est_plastique  \
# 0                10.0      0.090       0.0              d          False
# 1                 5.1      4.600       0.0              c          False
# 2                 9.7      0.464       0.0        unknown          False
# 3                 4.6      0.100       0.0        unknown           True
# 4                 0.0      0.000       0.0        unknown          False
# ...               ...        ...       ...            ...            ...
# 424597            1.7      0.470       0.0        unknown          False
# 424598            5.1      0.000       0.0        unknown          False
# 424599            9.7      0.130       0.0        unknown          False
# 424600            NaN        NaN       0.0        unknown          False
# 424601            0.1      1.500       0.0        unknown          False
#
#         est_palm  est_cocoa
# 0          False      False
# 1          False      False
# 2          False      False
# 3          False      False
# 4          False      False
# ...          ...        ...
# 424597     False      False
# 424598     False      False
# 424599     False      False
# 424600     False      False
# 424601     False      False
#
# [424602 rows x 20 columns]

# %%
df_total.duplicated().sum()
# Out:
# 4

# %%
df_total = df_total.drop_duplicates()

# %%
df_total = df_total.merge(bio_sansna_duplicate_gb, on=["product_name","brands_tags"], how="inner", suffixes=('', '_DROP')).filter(regex='^(?!.*_DROP)').drop_duplicates()

# %%
df_total
# Out:
#                         code                         product_name   quantity  \
# 0       00000000000026772226                                 Skyr      480 g
# 1                   03414569                                 Skyr        NaN
# 2                   04319111                                 Skyr      825 g
# 3              1033097270864                                 Skyr          4
# 4              3033491270864                                 Skyr  2 x 140 g
# ...                      ...                                  ...        ...
# 424593          996299394093                 Nutra'cake framboise        NaN
# 424594                997046              Chocolat noir patissier        NaN
# 424595                998042                       Saveur ABRICIT        NaN
# 424596               9990000                Lindt pâte à tartiner        NaN
# 424597            9995545314  Biodrink antioxydant pendant effort        NaN
#
#          brands_tags            countries_tags  serving_size  \
# 0             danone                 en:france           NaN
# 1             danone                 en:france          140g
# 2             danone                 en:france           NaN
# 3             danone                 en:france           NaN
# 4             danone  en:france,en:switzerland  1 pot (140g)
# ...              ...                       ...           ...
# 424593       delical                 en:france           NaN
# 424594  monoprix-bio                 en:france           NaN
# 424595        gerble                 en:france           NaN
# 424596         lindt                 en:france           NaN
# 424597   punch-power                 en:france           NaN
#
#                                                 image_url  \
# 0       https://images.openfoodfacts.org/images/produc...
# 1       https://images.openfoodfacts.org/images/produc...
# 2       https://images.openfoodfacts.org/images/produc...
# 3                                                     NaN
# 4       https://images.openfoodfacts.org/images/produc...
# ...                                                   ...
# 424593  https://images.openfoodfacts.org/images/produc...
# 424594  https://images.openfoodfacts.org/images/produc...
# 424595  https://images.openfoodfacts.org/images/produc...
# 424596  https://images.openfoodfacts.org/images/produc...
# 424597  https://images.openfoodfacts.org/images/produc...
#
#                                          ingredients_tags nutriscore_grade  \
# 0                                                     NaN                a
# 1       en:skimmed-milk,en:dairy,en:milk,en:lactic-fer...                a
# 2       en:skimmed-milk,en:dairy,en:milk,fr:ferments-l...              NaN
# 3                                                     NaN              NaN
# 4       en:skimmed-milk,en:dairy,en:milk,en:lactic-fer...                a
# ...                                                   ...              ...
# 424593                                                NaN              NaN
# 424594                                                NaN              NaN
# 424595                                                NaN              NaN
# 424596                                                NaN              NaN
# 424597                                                NaN              NaN
#
#         energy-kcal_100g  ...  saturated-fat_100g  sugars_100g  proteins_100g  \
# 0                   57.0  ...                0.10          3.9           10.0
# 1                   57.0  ...                0.10          3.9           10.0
# 2                    NaN  ...                 NaN          3.9           10.0
# 3                    NaN  ...                 NaN          NaN            NaN
# 4                   57.0  ...                0.10          3.9           10.0
# ...                  ...  ...                 ...          ...            ...
# 424593             381.0  ...                6.70         29.0           15.6
# 424594             578.0  ...               24.00         46.0            5.1
# 424595              45.0  ...                0.01          1.5            9.7
# 424596               NaN  ...                 NaN          NaN            NaN
# 424597             384.0  ...                0.10         59.0            0.1
#
#         salt_100g  nb_nocif  ecoscore_grade est_plastique  est_palm  \
# 0            0.09       0.0               d         False     False
# 1            0.09       0.0               b         False     False
# 2            0.09       0.0         unknown          True     False
# 3             NaN       0.0               d         False     False
# 4            0.10       0.0               b          True     False
# ...           ...       ...             ...           ...       ...
# 424593       0.80       0.0         unknown         False     False
# 424594       0.00       0.0         unknown         False     False
# 424595       0.13       0.0         unknown         False     False
# 424596        NaN       0.0         unknown         False     False
# 424597       1.50       0.0         unknown         False     False
#
#         est_cocoa  est_bio
# 0           False    False
# 1           False    False
# 2           False    False
# 3           False    False
# 4           False    False
# ...           ...      ...
# 424593      False    False
# 424594      False     True
# 424595      False    False
# 424596      False    False
# 424597      False     True
#
# [424598 rows x 21 columns]

# %%
df_total.duplicated().sum()
# Out:
# 0
